# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1eac1248-4efa-4572-811b-60b4719b0940" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1eac1248-4efa-4572-811b-60b4719b0940">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data= pd.read_csv("Q7.csv")

# %%
data.sample(5)
# Out:
#         Unnamed: 0  Points  Score  Weigh
# 19  Toyota Corolla    4.22  1.835  19.90
# 7        Merc 240D    3.69  3.190  20.00
# 1    Mazda RX4 Wag    3.90  2.875  17.02
# 20   Toyota Corona    3.70  2.465  20.01
# 22     AMC Javelin    3.15  3.435  17.30

# %%
data.describe()
# Out:
#           Points      Score      Weigh
# count  32.000000  32.000000  32.000000
# mean    3.596563   3.217250  17.848750
# std     0.534679   0.978457   1.786943
# min     2.760000   1.513000  14.500000
# 25%     3.080000   2.581250  16.892500
# 50%     3.695000   3.325000  17.710000
# 75%     3.920000   3.610000  18.900000
# max     4.930000   5.424000  22.900000

# %%
# mean for points, score and weigh
data[['Points','Score','Weigh']].mean()
# Out:
# Points     3.596563
# Score      3.217250
# Weigh     17.848750
# dtype: float64

# %%
# median for points, score and weigh
data[['Points','Score','Weigh']].median()
# Out:
# Points     3.695
# Score      3.325
# Weigh     17.710
# dtype: float64

# %%
# mode for points, score and weigh
data[['Points','Score','Weigh']].mode()
# Out:
#    Points  Score  Weigh
# 0    3.07   3.44  17.02
# 1    3.92    NaN  18.90

# %%
# Standard daviation for points, score and weigh
data[['Points','Score','Weigh']].std()
# Out:
# Points    0.534679
# Score     0.978457
# Weigh     1.786943
# dtype: float64

# %%
#variance for points
data.Points.var()
# Out:
# 0.2858813508064516

# %%
#variance for Score
data.Score.var()
# Out:
# 0.9573789677419354

# %%
#variance for Weigh
data.Weigh.var()
# Out:
# 3.193166129032258

# %%
data[['Points','Score','Weigh']].max()
# Out:
# Points     4.930
# Score      5.424
# Weigh     22.900
# dtype: float64

# %%
data[['Points','Score','Weigh']].min()
# Out:
# Points     2.760
# Score      1.513
# Weigh     14.500
# dtype: float64

# %%
# range for points, score and weigh
data[['Points','Score','Weigh']].max() - data[['Points','Score','Weigh']].min()
# Out:
# Points    2.170
# Score     3.911
# Weigh     8.400
# dtype: float64
